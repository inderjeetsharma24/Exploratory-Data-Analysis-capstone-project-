# %% [markdown]
# # **Project Name**    - Exploratory Data Analysis of Playstore Dataset

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Team Member -**Inderjeet

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Hi Everyone,
# The primary objective of this project is to conduct Exploratory Data Analysis (EDA) on the Google Play Store data to uncover patterns, relationships, and trends within the data. By employing statistical and graphical methods, the project aims to gain a deep understanding of the dataset's characteristics, identify potential outliers, and generate insights that can inform subsequent analysis or decision-making processes.
#
# #Key Components:
#
# ##-> Data Cleaning:
# Identifying missing value and drop or impute them with appropriate quantity.handeling duplicates and changing Data types of diffrent columnns.
# ##-> Univariate Analysis:
# Explore the distribution of individual variables through histograms, box plots, and kernel density plots.
# Identify outliers and anomalies that may require further investigation.
#
# ##-> Bivariate Analysis:
# Investigate relationships between pairs of variables to uncover potential correlations or associations.
# Employ scatter plots, correlation matrices, and heatmaps to visualize dependencies.
#
# ##-> Conclusion:
# Through this Exploratory Data Analysis, the project aims to offer a thorough understanding of the Google Play Store dataset, enabling stakeholders to make informed decisions based on the uncovered patterns and insights. The process involves a systematic examination of the data, statistical analyses, and visualization techniques to extract meaningful information, laying the foundation for further in-depth analyses and data-driven decision-making.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/inderjeetsharma24/Exploratory-Data-Analysis-capstone-project-Provide your GitHub Link here.

# %% [markdown]
# # **Let's Begin !**

# %% [markdown]
# ## **1. Understainding The Data**

# %% [markdown]
# ### Importing Libraries

# %%
from google.colab import drive
drive.mount('/content/drive')
#Import Libraries
import pandas as pd
import numpy as np
import missingno as msno  #missingo is a library to visualize missing values
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset

df = pd.read_csv("/content/drive/My Drive/Colab Notebooks/Play Store Data.csv")

user_df = pd.read_csv("/content/drive/My Drive/Colab Notebooks/User Reviews.csv")

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look

df = pd.read_csv("/content/drive/My Drive/Colab Notebooks/Play Store Data.csv")

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
no_rows = len(df.index)
no_col = len(df.columns)
print(f"no of rows and columns are {no_rows} and {no_col} respectively")
# Out:
# no of rows and columns are 10841 and 13 respectively

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
df['App'].value_counts()
# Out:
# App
# ROBLOX                                                9
# CBS Sports App - Scores, News, Stats & Watch Live     8
# ESPN                                                  7
# Duolingo: Learn Languages Free                        7
# Candy Crush Saga                                      7
#                                                      ..
# Meet U - Get Friends for Snapchat, Kik & Instagram    1
# U-Report                                              1
# U of I Community Credit Union                         1
# Waiting For U Launcher Theme                          1
# iHoroscope - 2018 Daily Horoscope & Astrology         1
# Name: count, Length: 9660, dtype: int64

# %%
#removing duplicated
df1 = df.drop_duplicates(subset="App")
df1['App'].value_counts() #relook at duplicates
# Out:
# App
# Photo Editor & Candy Camera & Grid & ScrapBook    1
# CK Pharmacies                                     1
# CK Call NEW                                       1
# Ck Coif                                           1
# CONTRACT KILLER: ZOMBIES                          1
#                                                  ..
# Bike Race Free - Top Motorcycle Racing Games      1
# Dance School Stories - Dance Dreams Come True     1
# 3D Bowling                                        1
# Mind Games Pro                                    1
# iHoroscope - 2018 Daily Horoscope & Astrology     1
# Name: count, Length: 9660, dtype: int64

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
df1.isna().sum()
# Out:
# App                  0
# Category             0
# Rating            1463
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
# Visualizing the missing values


# Visualize missing values as a matrix
msno.matrix(df1,figsize=(10,5), fontsize=12)
# Out:
# <Axes: >

# %%
# Visualize the number of missing
# values as a bar chart
msno.bar(df1,figsize=(10,5), fontsize=12)
# Out:
# <Axes: >

# %% [markdown]
# # After observing matrix and bar graph, we can see that there are significant amount of missing values in Rating column

# %%
# Visualize the correlation between the number of
# missing values in different columns as a heatmap
msno.heatmap(df1,figsize=(10,5), fontsize=12)
# Out:
# <Axes: >

# %% [markdown]
# Above heatmap confirm there is no correlation between missing values in rating column though there is correlation of 0.6 in content rating but that is not a concern since content rating has only few missing values

# %% [markdown]
# ## 2. ***Data Wrangling***

# %%
# dropping rows corresponding to the to the NaN values in the 'Type', 'Content Rating','Current Ver','Android Ver' columns.
dropna_colmn = ['Type', 'Content Rating','Current Ver','Android Ver']
for i in dropna_colmn:
 df1.dropna(axis=0, how='all', subset=[i], inplace = True)


df1.isna().sum()
# Out:
# <ipython-input-13-636f87e41de4>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.dropna(axis=0, how='all', subset=[i], inplace = True)
# <ipython-input-13-636f87e41de4>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.dropna(axis=0, how='all', subset=[i], inplace = True)
# <ipython-input-13-636f87e41de4>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
#Distribution of ratiang column
sns.distplot(df1['Rating'],color='blue')
# Out:
# <ipython-input-14-f15c12b9bd5e>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df1['Rating'],color='blue')
# <Axes: xlabel='Rating', ylabel='Density'>

# %%
#Filling values in Rating
#It is good to replace the missing values with median as distribution is skewed
mean_rating = round(df1[df1['Rating'].notna()]['Rating'].mean(),4)

median_rating = df1[df1['Rating'].notna()]['Rating'].median()

[mean_rating , median_rating]
# Out:
# [4.1733, 4.3]

# %%
# Replacing the NaN values in the 'Rating' colunm with its median value
df1['Rating'].fillna(value=median_rating,inplace=True)
# Out:
# <ipython-input-16-a6926c96312b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Rating'].fillna(value=median_rating,inplace=True)

# %%
#Changing data types of Review colmun
df1.info()

def convert_dtype(x):
  if 'M' in x:
    return float(x[:-1])*1e6
  else:
    return float(x)


df1['Reviews']=df1['Reviews'].apply(lambda y: convert_dtype(y))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9648 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             9648 non-null   object
#  1   Category        9648 non-null   object
#  2   Rating          9648 non-null   float64
#  3   Reviews         9648 non-null   object
#  4   Size            9648 non-null   object
#  5   Installs        9648 non-null   object
#  6   Type            9648 non-null   object
#  7   Price           9648 non-null   object
#  8   Content Rating  9648 non-null   object
#  9   Genres          9648 non-null   object
#  10  Last Updated    9648 non-null   object
#  11  Current Ver     9648 non-null   object
#  12  Android Ver     9648 non-null   object
# dtypes: float64(1), object(12)
# memory usage: 1.0+ MB
# <ipython-input-17-b9167eb29512>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df1.info()
df1['Price'].value_counts()


def convert_dtype1(x):
  if '$' in x:
    return float(x[1:])
  else:
    return float(x)


df1['Price']=df1['Price'].apply(lambda y: convert_dtype1(y))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9648 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             9648 non-null   object
#  1   Category        9648 non-null   object
#  2   Rating          9648 non-null   float64
#  3   Reviews         9648 non-null   float64
#  4   Size            9648 non-null   object
#  5   Installs        9648 non-null   object
#  6   Type            9648 non-null   object
#  7   Price           9648 non-null   object
#  8   Content Rating  9648 non-null   object
#  9   Genres          9648 non-null   object
#  10  Last Updated    9648 non-null   object
#  11  Current Ver     9648 non-null   object
#  12  Android Ver     9648 non-null   object
# dtypes: float64(2), object(11)
# memory usage: 1.0+ MB
# <ipython-input-18-bc7807879112>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df1["Last Updated"] = pd.to_datetime(df1['Last Updated'])
df1.head()
# Out:
# <ipython-input-19-e5b284ef9499>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["Last Updated"] = pd.to_datetime(df1['Last Updated'])
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#     Reviews  Size     Installs  Type  Price Content Rating  \
# 0     159.0   19M      10,000+  Free    0.0       Everyone
# ...

# %%
df1['Installs'].value_counts()

def convert_dtype2(x):

  if '+' and ',' in x:
    new = int(x[:-1].replace(',',''))
    return new
  elif '+' in x:
    new1 = int(x[:-1])
    return new1
  else:
    return int(x)


df1['Installs']=df1['Installs'].apply(lambda y: convert_dtype2(y))
# Out:
# <ipython-input-20-526253dde8a2>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Installs']=df1['Installs'].apply(lambda y: convert_dtype2(y))

# %%
def convert_dtype3(x):
  '''
  This function converts all the valid entries in KB to MB and returns the result in float datatype.
  '''
  try:
    if 'M' in x:
      return float(x[:-1])
    elif 'k' in x:
      return round(float(x[:-1])/1024, 4)
    else:
      return float(x)
  except:
    return x


df1['Size']=df1['Size'].apply(lambda y: convert_dtype3(y))




df1['Size'] = df1['Size'].apply(lambda x: str(x).replace('Varies with device', 'NaN') if 'Varies with device' in str(x) else str(x))


df1['Size']=df1['Size'].apply(lambda y: convert_dtype3(y))


df1.Size
# Out:
# <ipython-input-21-f17e37e15f3c>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Size']=df1['Size'].apply(lambda y: convert_dtype3(y))
# <ipython-input-21-f17e37e15f3c>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Size'] = df1['Size'].apply(lambda x: str(x).replace('Varies with device', 'NaN') if 'Varies with device' in str(x) else str(x))
# <ipython-input-21-f17e37e15f3c>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %% [markdown]
# ## ***3. Data Vizualization***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
col_list = ["red","green","orange"]
for i in range(3,len(df1["Category"].unique())):
  col_list.append("pink")
print(col_list)

df1['Category'].value_counts().plot.bar(color = col_list)
# Out:
# ['red', 'green', 'orange', 'pink', 'pink', 'pink', 'pink', 'pink', 'pink', 'pink', 'pink', 'pink', 'pink', 'pink', 'pink', 'pink', 'pink', 'pink', 'pink', 'pink', 'pink', 'pink', 'pink', 'pink', 'pink', 'pink', 'pink', 'pink', 'pink', 'pink', 'pink', 'pink', 'pink']
# <Axes: xlabel='Category'>

# %%
plt.figure(figsize=(18,18))
plt.pie(df1.Category.value_counts(), labels=df1.Category.value_counts().index, autopct='%1.2f%%')
my_circle = plt.Circle( (0,0), 0.50, color='white')
p=plt.gcf()
p.gca().add_artist(my_circle)
plt.title('% of apps share in each Category', fontsize = 25)
plt.show()

# %% [markdown]
# **One can easily observe that most of the apps belongs to three categories namely FAMILY,GAMES and TOOLS**

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code

sns.barplot(x =df1.groupby('Category')['Rating'].mean(), y = df1['Category'].unique())
# Out:
# <Axes: xlabel='Rating'>

# %% [markdown]
# **By looking at bar chart we can be certain that there is no significant pattern in category and ratings**

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
print(df1.head())
df1['Type'].value_counts().plot.bar(color = ["Green","blue"])
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#     Reviews  Size  Installs  Type  Price Content Rating  \
# 0     159.0  19.0     10000  Free    0.0       Everyone
# 1     967.0  14.0    500000  Free    0.0       Everyone
# 2   87510.0   8.7   5000000  Free    0.0       Everyone
# 3  215644.0  25.0  50000000  Free    0.0           Teen
# 4     967.0   2.8    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver
# 0               Art & Design   2018-01-07               1.0.0  4.0.3 and up
# ...

# %% [markdown]
# **Above bar char confirms that majority of apps are free**

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
plt.figure(figsize = (10,5))

# Convert 'Rating' column to numeric type
df1['Rating'] = pd.to_numeric(df1['Rating'], errors='coerce')

# Drop non-numeric columns before calculating correlation
numeric_df = df1.select_dtypes(include=['number'])
sns.heatmap(numeric_df.corr(), annot= True)

plt.title('Correlation Heatmap for Playstore Data', size=20)
# Out:
# <ipython-input-28-f93e145b8a28>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Rating'] = pd.to_numeric(df1['Rating'], errors='coerce')
# Text(0.5, 1.0, 'Corelation Heatmap for Playstore Data')

# %% [markdown]
# **There is not much correlation between features but Reviews and numbers of installs are positily correlated by factor of 0.63,But this has no significance as it is normal for reviews to increase with numbers of intalls.**

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
sns.pairplot(df1, hue ='Type')
df1.Size
# Out:
# 0        19.0
# 1        14.0
# 2         8.7
# 3        25.0
# 4         2.8
#          ...
# 10836    53.0
# 10837     3.6
# 10838     9.5
# 10839     NaN
# 10840    19.0
# Name: Size, Length: 9648, dtype: float64

# %% [markdown]
# #### Chart - 6

# %% [markdown]
# **Now we will merge playstore dataset and user reviews dataset and try to uncover the patterns inside**

# %%
# Chart - 6 visualization code


user_df = user_df.dropna()
merged_df = pd.merge(df1, user_df, on='App', how = "inner")
merged_df.head()
# Out:
#                    App        Category  Rating  Reviews  Size  Installs  Type  \
# 0  Coloring book moana  ART_AND_DESIGN     3.9    967.0  14.0    500000  Free
# 1  Coloring book moana  ART_AND_DESIGN     3.9    967.0  14.0    500000  Free
# 2  Coloring book moana  ART_AND_DESIGN     3.9    967.0  14.0    500000  Free
# 3  Coloring book moana  ART_AND_DESIGN     3.9    967.0  14.0    500000  Free
# 4  Coloring book moana  ART_AND_DESIGN     3.9    967.0  14.0    500000  Free
#
#    Price Content Rating                     Genres Last Updated Current Ver  \
# 0    0.0       Everyone  Art & Design;Pretend Play   2018-01-15       2.0.0
# 1    0.0       Everyone  Art & Design;Pretend Play   2018-01-15       2.0.0
# 2    0.0       Everyone  Art & Design;Pretend Play   2018-01-15       2.0.0
# 3    0.0       Everyone  Art & Design;Pretend Play   2018-01-15       2.0.0
# 4    0.0       Everyone  Art & Design;Pretend Play   2018-01-15       2.0.0
#
# ...

# %%
#top transelated review
app=merged_df.groupby(['App','Category','Sentiment'])['Translated_Review'].count().reset_index()
app=pd.DataFrame(app)
app=app.sort_values(by=['Translated_Review'], ascending=False).reset_index()

app.head(200)
# Out:
#      index                             App            Category Sentiment  \
# 0     2115                      Helix Jump                GAME  Positive
# 1     1279  Duolingo: Learn Languages Free           EDUCATION  Positive
# 2      824        Calorie Counter - Macros  HEALTH_AND_FITNESS  Positive
# 3      664                      Bowmasters                GAME  Positive
# 4      827  Calorie Counter - MyFitnessPal  HEALTH_AND_FITNESS  Positive
# ..     ...                             ...                 ...       ...
# 195    486                     Bad Piggies              FAMILY  Positive
# 196    402                        BBC News  NEWS_AND_MAGAZINES  Positive
# 197    484                     Bad Piggies              FAMILY  Negative
# 198   1518                 Fast Secure VPN               TOOLS  Positive
# 199   2068               Hacker's Keyboard        PRODUCTIVITY  Positive
#
#      Translated_Review
# 0                  209
# 1                  200
# ...

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
merged_df['Sentiment'].value_counts().plot.bar(color = ["green","red","blue"])
# Out:
# <Axes: xlabel='Sentiment'>

# %% [markdown]
# **Most of the reviews are positive but Negetive reviews are more than the neutral one's which is a concern for bussiness partners**

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
# Reacation calculation on top 3 category app

# Reacation calculation on top 3 category app
x=['GAME','FAMILY','HEALTH_AND_FITNESS']
for i in x:

    df5=merged_df[merged_df['Category']==i]

# Compare in positive and negetive review
    plt.figure(figsize=(5, 5))
    sns.countplot(df5, x="Sentiment")
    plt.title(f'{i} app Sentiment')
    plt.ylabel('Number of Translated_Review')
    plt.show()

# %% [markdown]
# **HEALTH AND FITNESS apps are doing well with negtive reviews but Family and games need to improve**

# %% [markdown]
# #### Chart - 9 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
fig, axes = plt.subplots(figsize=(8, 8))

# Select only numerical columns for correlation calculation
numerical_df = merged_df.select_dtypes(include=['number'])

sns.heatmap(numerical_df.corr(), ax=axes, annot=True, cmap=plt.cm.Blues ,linewidths=0.1, fmt='.2f', square=True)
plt.show()

# %% [markdown]
# #### Chart - 10 - Pair Plot

# %%
# Pair Plot visualization code
sns.pairplot(merged_df, hue ='Type')
merged_df.Size
# Out:
# 0        14.0
# 1        14.0
# 2        14.0
# 3        14.0
# 4        14.0
#          ...
# 35924     NaN
# 35925     NaN
# 35926     NaN
# 35927     NaN
# 35928     NaN
# Name: Size, Length: 35929, dtype: float64
